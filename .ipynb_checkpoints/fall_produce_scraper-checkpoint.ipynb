# %%
# Import dependencies
from bs4 import BeautifulSoup
import requests

# %%
# URL of page to be scraped
url = 'https://snaped.fns.usda.gov/seasonal-produce-guide/fall'

# %%
# Retrieve page with the requests module
response = requests.get(url)

# %%
# Create BeautifulSoup object
soup = BeautifulSoup(response.text, 'lxml')

# %%
# Examine the results, then determine element that contains sought info
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="SNAP Education Connection" property="og:site_name"/>
#   <link href="https://snaped.fns.usda.gov/seasonal-produce-guide/fall" rel="canonical"/>
#   <meta content="Fall" property="og:title"/>
#   <meta content="https://snaped.fns.usda.gov" property="og:image"/>
#   <meta content="Drupal 8 (https://www.drupal.org)" name="Generator"/>
#   <meta content="width" name="MobileOptimized"/>
#   <meta content="true" name="HandheldFriendly"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    Fall | SNAP-Ed
#   </title>
#   <!-- Favicons
#     ================================================== -->
#   <!-- 128x128 -->
#   <link href="/themes/usda/img/favicons/favicon.ico" rel="shortcut icon" type="image/ico"/>
#   <link href="/themes/usda/img/favicons/favicon.png" rel="icon" type="image/png"/>
#   <!-- 192x192, as recommended for Android
#     http://updates.html5rocks.com/2014/11/Support-for-theme-color-in-Chrome-39-for-Android
#     -->
#   <link href="/themes/usda/img/favicons/favicon-192.png" rel="icon" sizes="192x192" type="image/png"/>
#   <!-- 57x57 (precomposed) for iPhone 3GS, pre-2011 iPod Touch and older Android devices -->
#   <link href="/themes/usda/img/favicons/favicon-57.png" rel="apple-touch-icon-precomposed"/>
#   <!-- 72x72 (precomposed) for 1st generation iPad, iPad 2 and iPad mini -->
#   <link href="/themes/usda/img/favicons/favicon-72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
#   <!-- 114x114 (precomposed) for iPhone 4, 4S, 5 and post-2011 iPod Touch -->
#   <link href="/themes/usda/img/favicons/favicon-114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
#   <!-- 144x144 (precomposed) for iPad 3rd and 4th generation -->
#   <link href="/themes/usda/img/favicons/favicon-144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
#   <link href="/sites/default/files/css/css_Fiqn-6rnLCxgfsWD2KodaLpWZIuxRJbm1y75LlLYJ8Y.css" media="all" rel="stylesheet"/>
#   <link href="/sites/default/files/css/css_BwIbzYevjhlciksIszcYQfWUsoB9QpJzetMjeGgxaQU.css" media="all" rel="stylesheet"/>
#   <link href="/sites/default/files/css/css_enT-WiWnAUhqE5Q8rMmgtniaeV90W0D_PY1WHlC2QA0.css" media="print" rel="stylesheet"/>
#   <!--[if lte IE 8]>
# <script src="/sites/default/files/js/js_VtafjXmRvoUgAzqzYTA3Wrjkx9wcWhjP0G4ZnnqRamA.js"></script>
# <![endif]-->
#   <!-- We participate in the US government's analytics program. See the data at analytics.usa.gov. -->
#   <script async="" id="_fed_an_ua_tag" src="https://dap.digitalgov.gov/Universal-Federated-Analytics-Min.js?agency=USDA&amp;sp=lookup,locate&amp;exts=pdf,xls,zip,jpg,gif,mp3&amp;dclink=true&amp;yt=true&amp;enhlink=true">
#   </script>
#   <!-- Google Analytics USDA -->
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#       (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#       m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#       })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#       ga('create', 'UA-27627304-1', 'auto');
#       ga('create', 'UA-96909960-1', 'auto', {'name': 'usdaTracker'}); // New tracker.
#
#       ga('send', 'pageview');
#       ga('usdaTracker.send', 'pageview'); // Send page view for new tracker
#   </script>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-32115092-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#     function gtag() {dataLayer.push(arguments);}
#     gtag('js', new Date());
#     gtag('config', 'UA-32115092-1');
#   </script>
#   <script>
#    var w=window;if(w.performance||w.mozPerformance||w.msPerformance||w.webkitPerformance){var d=document;AKSB=w.AKSB||{},AKSB.q=AKSB.q||[],AKSB.mark=AKSB.mark||function(e,_){AKSB.q.push(["mark",e,_||(new Date).getTime()])},AKSB.measure=AKSB.measure||function(e,_,t){AKSB.q.push(["measure",e,_,t||(new Date).getTime()])},AKSB.done=AKSB.done||function(e){AKSB.q.push(["done",e])},AKSB.mark("firstbyte",(new Date).getTime()),AKSB.prof={custid:"450736",ustr:"",originlat:"0",clientrtt:"25",ghostip:"23.15.240.197",ipv6:false,pct:"10",clientip:"76.167.229.95",requestid:"41e3301",region:"35770",protocol:"",blver:14,akM:"dscb",akN:"ae",akTT:"O",akTX:"1",akTI:"41e3301",ai:"289075",ra:"false",pmgn:"",pmgi:"",pmp:"",qc:""},function(e){var _=d.createElement("script");_.async="async",_.src=e;var t=d.getElementsByTagName("script"),t=t[t.length-1];t.parentNode.insertBefore(_,t)}(("https:"===d.location.protocol?"https:":"http:")+"//ds-aksb-a.akamaihd.net/aksb.min.js")}
#   </script>
#  </head>
#  <body class="path-node page-node-type-landing-page">
#   <div class="dialog-off-canvas-main-canvas" data-off-canvas-main-canvas="">
#    <header aria-label="Page Header" class="usa-header usa-header-extended">
#     <a class="usa-skipnav" href="#main-content">
#      Skip to main content
#     </a>
#     <div class="usa-banner">
#      <div class="usa-accordion">
#       <section aria-label="Official United States Government Website Disclaimer" class="usa-banner-header">
#        <div class="usa-grid usa-banner-inner">
#         <img alt="U.S. flag" src="/themes/usda/img/favicons/flag-favicon-57.png"/>
#         <p>
#          An official website of the United States government
#         </p>
#         <button aria-controls="gov-banner" aria-expanded="false" class="usa-accordion-button usa-banner-button">
#          <span class="usa-banner-button-text">
#           Here’s how you know
#          </span>
#         </button>
#        </div>
#       </section>
#       <div aria-hidden="true" class="usa-banner-content usa-grid usa-accordion-content" id="gov-banner">
#        <div class="usa-banner-guidance-gov usa-width-one-half">
#         <img alt="Dot gov" class="usa-banner-icon usa-media_block-img" src="/themes/usda/img/icon-dot-gov.svg"/>
#         <div class="usa-media_block-body">
#          <p>
#           <strong>
#            The .gov means it’s official.
#           </strong>
#           <br/>
#           Federal government websites always use a .gov or .mil domain. Before sharing sensitive information online, make sure you’re on a .gov or .mil site by inspecting your browser’s address (or “location”) bar.
#          </p>
#         </div>
#        </div>
#        <div class="usa-banner-guidance-ssl usa-width-one-half">
#         <img alt="SSL" class="usa-banner-icon usa-media_block-img" src="/themes/usda/img/icon-https.svg"/>
#         <div class="usa-media_block-body">
#          <p>
#           This site is also protected by an SSL (Secure Sockets Layer) certificate that’s been signed by the U.S. government. The
#           <strong>
#            https://
#           </strong>
#           means all transmitted data is encrypted  — in other words, any information or browsing history that you provide is transmitted securely.
#          </p>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="usa-banner">
#      <div class="usa-navbar">
#       <button class="usa-menu-btn">
#        Menu
#       </button>
#       <div class="usa-logo">
#        <span class="usda-logo">
#         <img alt="USDA Logo" class="usda-logo-img" src="/themes/usda/img/usda-symbol.svg"/>
#        </span>
#        <a aria-label="The U.S. Department of Agriculture Home Page" class="usda-logo-text" href="/" rel="home" title="Home">
#         <h3>
#          SNAP-Ed Connection
#         </h3>
#         <span>
#          U.S. Department of Agriculture
#         </span>
#        </a>
#       </div>
#      </div>
#     </div>
#     <nav aria-label="Navigation" class="usa-nav">
#      <div class="usa-nav-inner">
#       <button class="usa-nav-close">
#        <img alt="close" src="/themes/usda/img/close.svg"/>
#       </button>
#       <nav aria-labelledby="block-mainnavigation-menu" class="usda-block" data-block-plugin-id="system_menu_block:main" id="block-mainnavigation">
#        <h2 class="usa-sr-only" id="block-mainnavigation-menu">
#         Main navigation
#        </h2>
#        <ul class="usa-nav-primary usa-accordion">
#         <li>
#          <a class="usa-nav-link" data-drupal-link-system-path="&lt;front&gt;" href="/">
#           <span>
#            Home
#           </span>
#          </a>
#         </li>
#         <li>
#          <button aria-controls="side-nav-2" aria-expanded="false" class="usa-accordion-button usa-nav-link">
#           <span>
#            SNAP-Ed Works!
#           </span>
#          </button>
#          <div class="usa-nav-submenu" id="side-nav-2">
#           <ul class="usda-nav-submenu">
#            <li class="usda-nav-overview">
#             <a data-drupal-link-system-path="node/835" href="/snap-ed-works">
#              <span>
#               SNAP-Ed Works!
#              </span>
#             </a>
#            </li>
#            <li>
#             <a data-drupal-link-system-path="success-stories" href="/success-stories">
#              Success Stories
#             </a>
#            </li>
#            <li>
#             <a data-drupal-link-system-path="node/588" href="/state-snap-ed-programs">
#              State SNAP-Ed Programs
#             </a>
#            </li>
#            <li>
#             <a data-drupal-link-system-path="node/971" href="/snap-ed-works/policy-systems-and-environmental-change">
#              Policy, Systems, and Environmental Change
#             </a>
#            </li>
#            <li>
#             <a data-drupal-link-system-path="node/920" href="/snap-ed-works/social-marketing">
#              Social Marketing
#             </a>
#            </li>
#            <li>
#             <a data-drupal-link-system-path="node/1817" href="/snap-ed-works/nutrition-education">
#              Nutrition Education
#             </a>
#            </li>
#           </ul>
#          </div>
#         </li>
#         <li>
#          <button aria-controls="side-nav-3" aria-expanded="false" class="usa-accordion-button usa-nav-link usa-current">
#           <span>
#            Nutrition Education
#           </span>
#          </button>
#          <div class="usa-nav-submenu" id="side-nav-3">
#           <ul class="usda-nav-submenu">
#            <li class="usda-nav-overview">
#             <a data-drupal-link-system-path="node/1817" href="/snap-ed-works/nutrition-education">
#              <span>
#               Nutrition Education
#              </span>
#             </a>
#            </li>
#            <li>
#             <a data-drupal-link-system-path="node/576" href="/library">
#              SNAP-Ed Library
#             </a>
#            </li>
#            <li>
#             <a data-drupal-link-system-path="node/715" href="/photo-gallery">
#              Photo Gallery
#             </a>
#            </li>
#            <li>
#             <a data-drupal-link-system-path="node/842" href="/seasonal-produce-guide">
#              Seasonal Produce Guide
#             </a>
#            </li>
#            <li>
#             <a data-drupal-link-system-path="node/1556" href="/nutrition-education/recipes">
#              Recipes
#             </a>
#            </li>
#            <li>
#             <a data-drupal-link-system-path="node/1851" href="/nutrition-education/healthy-thrifty-holiday-menus">
#              Healthy, Thrifty Holiday Menus
#             </a>
#            </li>
#            <li>
#             <a data-drupal-link-system-path="node/906" href="/nutrition-education/fns-curricula">
#              FNS Curricula
#             </a>
#            </li>
#            <li>
#             <a data-drupal-link-system-path="node/919" href="/nutrition-education/nutrition-education-materials">
#              Nutrition Education Materials
#             </a>
#            </li>
#            <li>
#             <a data-drupal-link-system-path="node/1197" href="/nutrition-education/spanish-language-materials">
#              Spanish Language Materials
#             </a>
#            </li>
#           </ul>
#          </div>
#         </li>
#         <li>
#          <button aria-controls="side-nav-4" aria-expanded="false" class="usa-accordion-button usa-nav-link">
#           <span>
#            Program Administration
#           </span>
#          </button>
#          <div class="usa-nav-submenu" id="side-nav-4">
#           <ul class="usda-nav-submenu">
#            <li class="usda-nav-overview">
#             <a data-drupal-link-system-path="node/578" href="/program-administration">
#              <span>
#               Program Administration
#              </span>
#             </a>
#            </li>
#            <li>
#             <a data-drupal-link-system-path="node/851" href="/program-administration/ears-form-training">
#              EARS Form &amp; Training
#             </a>
#            </li>
#            <li>
#             <a data-drupal-link-system-path="node/912" href="/program-administration/guidance-and-templates">
#              Guidance and Templates
#             </a>
#            </li>
#            <li>
#             <a data-drupal-link-system-path="evaluation/evaluation-tools" href="/evaluation/evaluation-tools">
#              Evaluation Tools
#             </a>
#            </li>
#            <li>
#             <a data-drupal-link-system-path="node/916" href="/program-administration/funding-allocations">
#              Funding Allocations
#             </a>
#            </li>
#            <li>
#             <a data-drupal-link-system-path="node/911" href="/program-administration/snap-ed-evaluation-framework">
#              SNAP-Ed Evaluation Framework
#             </a>
#            </li>
#            <li>
#             <a data-drupal-link-system-path="node/910" href="/program-administration/snap-ed-toolkit-strategies-interventions">
#              SNAP-Ed Toolkit Strategies &amp; Interventions
#             </a>
#            </li>
#            <li>
#             <a data-drupal-link-system-path="node/2304" href="/program-administration/farm-bill-regulations">
#              Farm Bill &amp; Regulations
#             </a>
#            </li>
#            <li>
#             <a data-drupal-link-system-path="node/2267" href="/program-administration/regional-evaluation-reports">
#              Regional Evaluation Reports
#             </a>
#            </li>
#           </ul>
#          </div>
#         </li>
#         <li>
#          <button aria-controls="side-nav-5" aria-expanded="false" class="usa-accordion-button usa-nav-link">
#           <span>
#            Training
#           </span>
#          </button>
#          <div class="usa-nav-submenu" id="side-nav-5">
#           <ul class="usda-nav-submenu">
#            <li class="usda-nav-overview">
#             <a data-drupal-link-system-path="node/579" href="/training">
#              <span>
#               Training
#              </span>
#             </a>
#            </li>
#            <li>
#             <a data-drupal-link-system-path="node/921" href="/training/snap-ed-webinars">
#              SNAP-Ed Webinars
#             </a>
#            </li>
#            <li>
#             <a data-drupal-link-system-path="node/932" href="/training/conference-calendar">
#              Conference Calendar
#             </a>
#            </li>
#            <li>
#             <a data-drupal-link-system-path="node/1268" href="/training/online-training">
#              Online Training
#             </a>
#            </li>
#            <li>
#             <a data-drupal-link-system-path="node/1365" href="/training/webinars">
#              Webinars
#             </a>
#            </li>
#           </ul>
#          </div>
#         </li>
#        </ul>
#       </nav>
#       <div>
#        <div class="header-card">
#         <a class="header-card-button" href="/e-bulletin-signup">
#          Get SNAP-Ed Updates!
#         </a>
#        </div>
#       </div>
#       <form action="https://usdasearch.usda.gov/search" class="usa-search usa-search-small js-search-form" method="get">
#        <div role="search">
#         <input name="utf8" type="hidden" value="✓"/>
#         <input id="affiliate" name="affiliate" type="hidden" value="snaped_connection"/>
#         <label class="usa-sr-only" for="header-search">
#          Search usda.gov
#         </label>
#         <input accesskey="i" autocomplete="off" id="header-search" name="query" type="search"/>
#         <button type="submit">
#          <span class="usa-sr-only">
#           Search
#          </span>
#         </button>
#         <input name="commit" type="hidden" value="Search"/>
#        </div>
#       </form>
#       <div class="usa-nav-secondary">
#        <nav aria-labelledby="block-utilitynavigation-menu" class="usda-block" data-block-plugin-id="system_menu_block:utility-navigation" id="block-utilitynavigation">
#         <h2 class="usa-sr-only" id="block-utilitynavigation-menu">
#          Utility Navigation
#         </h2>
#         <ul class="usa-unstyled-list usa-nav-secondary-links">
#          <li>
#           <a data-drupal-link-system-path="node/917" href="/about">
#            About
#           </a>
#          </li>
#          <li>
#           <a data-drupal-link-system-path="node/901" href="/contact-us">
#            Contact Us
#           </a>
#          </li>
#          <li>
#           <a href="https://www.fns.usda.gov/">
#            FNS
#           </a>
#          </li>
#          <li>
#           <a href="https://www.usda.gov" title="The main USDA website">
#            USDA.gov
#           </a>
#          </li>
#         </ul>
#        </nav>
#       </div>
#      </div>
#     </nav>
#    </header>
#    <div class="usa-overlay">
#    </div>
#    <div class="usda-block" data-block-plugin-id="system_breadcrumb_block" id="block-breadcrumbs">
#     <nav aria-labelledby="system-breadcrumb" class="usa-grid">
#      <h2 class="visually-hidden" id="system-breadcrumb">
#       Breadcrumb
#      </h2>
#      <ol class="usda-breadcrumb-list">
#       <li class="usda-breadcrumb-item">
#        <a href="/">
#         SNAP-Ed
#        </a>
#       </li>
#       <li class="usda-breadcrumb-item">
#        <a href="/snap-ed-works/nutrition-education">
#         Nutrition Education
#        </a>
#       </li>
#       <li class="usda-breadcrumb-item">
#        <a href="/seasonal-produce-guide">
#         Seasonal Produce Guide
#        </a>
#       </li>
#       <li class="usda-breadcrumb-item">
#        Fall
#       </li>
#      </ol>
#     </nav>
#    </div>
#    <main id="main-content">
#     <div class="hidden" data-drupal-messages-fallback="">
#     </div>
#     <div class="usda-block usda-page-title-block usa-grid" data-block-plugin-id="page_title_block" id="block-usda-page-title">
#      <h1 class="usda-page-title">
#       <span>
#        Fall
#       </span>
#      </h1>
#     </div>
#     <div class="usda-block" data-block-plugin-id="system_main_block" id="block-mainpagecontent">
#      <article aria-label="Fall">
#       <div>
#        <div class="paragraph paragraph--type-view paragraph--view-mode-default">
#         <div class="usa-grid">
#          <div>
#           <div class="views-element-container">
#            <div class="js-view-dom-id-67d3157d78069dc12a10a1d33ff82bd907b4eb04b3d4bb42a21adff4f64d3d96">
#             <header>
#              <h2>
#               Seasonal Produce
#              </h2>
#             </header>
#             <div>
#              <ul class="usa-grid usa-unstyled-list seasonal-produce--season-landing">
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/apples">
#                 <img alt="green and red apples in a bowl on a wood background" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/apples_2.jpg?h=65b39431&amp;itok=FZp7Ge2l" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/apples" hreflang="en">
#                  Apples
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/bananas">
#                 <img alt="a bunch of bananas on a wood table" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/banana.jpg?h=dbf19296&amp;itok=T3BrgO_J" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/bananas" hreflang="en">
#                  Bananas
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/beets">
#                 <img alt="red and purple beets with green tops" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/beets.jpg?h=c8b8df1c&amp;itok=1x7k5Xrf" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/beets" hreflang="en">
#                  Beets
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/bell-peppers">
#                 <img alt="red, yellow, and green bell peppers" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/bell%20peppers.jpg?h=9f30bee3&amp;itok=WhvCEkKG" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/bell-peppers" hreflang="en">
#                  Bell Peppers
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/broccoli">
#                 <img alt="broccoli florets in a bowl" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/broccoli.jpg?h=65b39431&amp;itok=skCfeGZG" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/broccoli" hreflang="en">
#                  Broccoli
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/brussels-sprouts">
#                 <img alt="brussels sprouts on a table" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/brusselssprouts.jpg?h=c8b8df1c&amp;itok=36DhgAvL" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/brussels-sprouts" hreflang="en">
#                  Brussels Sprouts
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/cabbage">
#                 <img alt="Green cabbage on a wood table" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/cabbage.jpg?h=ea25e381&amp;itok=aqhtufS3" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/cabbage" hreflang="en">
#                  Cabbage
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/carrots">
#                 <img alt="different color of carrots with green tops" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/carrots.jpg?h=c8b8df1c&amp;itok=yaoDvQTQ" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/carrots" hreflang="en">
#                  Carrots
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/cauliflower">
#                 <img alt="head of cauliflower with a couple of florets" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/cauliflower.jpg?h=c8b8df1c&amp;itok=bnzAwf2T" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/cauliflower" hreflang="en">
#                  Cauliflower
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/celery">
#                 <img alt="cut celery in a white bowl with celery stalks in the background" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/celery.jpg?h=8bf7d235&amp;itok=AsUzQjo2" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/celery" hreflang="en">
#                  Celery
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/collard-greens">
#                 <img alt="leaf of collard greens" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/collards.jpg?itok=6A4jXVVj" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/collard-greens" hreflang="en">
#                  Collard Greens
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/cranberries">
#                 <img alt="cranberries in a bowl" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/cranberries.jpg?itok=y1xUnNIj" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/cranberries" hreflang="en">
#                  Cranberries
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/garlic">
#                 <img alt="whole heads of garlic on a wood table" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/garlic.jpg?itok=fB8Rrr2u" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/garlic" hreflang="en">
#                  Garlic
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/ginger">
#                 <img alt="ginger root" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/ginger.jpg?itok=kb6qYoH3" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/ginger" hreflang="en">
#                  Ginger
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/grapes">
#                 <img alt="red, green, and purple grapes" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/grapes_0.jpg?itok=uVxpjDcD" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/grapes" hreflang="en">
#                  Grapes
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/green-beans">
#                 <img alt="Green beans on a wood table" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/green%20beans.jpg?itok=JQTNdrGG" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/green-beans" hreflang="en">
#                  Green Beans
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/kale">
#                 <img alt="leaves of kale on a table" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/kale.jpg?itok=hOnCv-wz" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/kale" hreflang="en">
#                  Kale
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/kiwifruit">
#                 <img alt="whole and sliced kiwi" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/kiwi.jpg?itok=rCd7ypJ1" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/kiwifruit" hreflang="en">
#                  Kiwifruit
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/lemons">
#                 <img alt="whole lemons and lemon slices on a wood table" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/lemons.jpg?itok=NSydoZ4S" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/lemons" hreflang="en">
#                  Lemons
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/lettuce">
#                 <img alt="green and red lettuce" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/lettuce.jpg?itok=UbGxH1ZB" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/lettuce" hreflang="en">
#                  Lettuce
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/limes">
#                 <img alt="whole limes and cut limes in a basket on a table" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/limes.jpg?itok=J91TylfN" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/limes" hreflang="en">
#                  Limes
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/mangos">
#                 <img alt="whole mango and cut up mango in a bowl on a wood table" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/mango.jpg?itok=yf6ewLn_" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/mangos" hreflang="en">
#                  Mangos
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/mushrooms">
#                 <img alt="Mushrooms on a napkin" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/mushrooms.jpg?h=b754914e&amp;itok=NUymRdp6" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/mushrooms" hreflang="en">
#                  Mushrooms
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/onions">
#                 <img alt="onions on a cutting board" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/onions.jpg?itok=qQUPd5lW" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/onions" hreflang="en">
#                  Onions
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/parsnips">
#                 <img alt="parsnips with green tops" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/parsnip.jpg?itok=NPDuq-f3" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/parsnips" hreflang="en">
#                  Parsnips
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/pears">
#                 <img alt="Pears on a table" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/pears.jpg?itok=k85PAL3p" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/pears" hreflang="en">
#                  Pears
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/peas">
#                 <img alt="pea pods on a table" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/peas.jpg?itok=pyiIlyDB" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/peas" hreflang="en">
#                  Peas
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/pineapples">
#                 <img alt="sliced pineapple" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/pineapple.jpg?itok=7CODtRaW" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/pineapples" hreflang="en">
#                  Pineapples
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/potatoes">
#                 <img alt="Red and white potatoes in a crate" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/potatoes.jpg?itok=uoUOv_Z2" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/potatoes" hreflang="en">
#                  Potatoes
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/pumpkin">
#                 <img alt="whole and sliced pumpkins" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/pumpkin.jpg?itok=xNYfL4o6" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/pumpkin" hreflang="en">
#                  Pumpkin
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/radishes">
#                 <img alt="radishes with their green tops in a bowl" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/radish.jpg?itok=RBJqdE1j" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/radishes" hreflang="en">
#                  Radishes
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/raspberries">
#                 <img alt="overflowing bowl of raspberries" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/raspberries.jpg?itok=GRLnFDrp" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/raspberries" hreflang="en">
#                  Raspberries
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/rutabagas">
#                 <img alt="rutabaga in a basket" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/rutabaga.jpg?itok=IfGa0cn9" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/rutabagas" hreflang="en">
#                  Rutabagas
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/spinach">
#                 <img alt="spinach leaves" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/spinach.jpg?itok=_Xnqo99p" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/spinach" hreflang="en">
#                  Spinach
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/sweet-potatoes-yams">
#                 <img alt="whole and sliced sweet potatoes" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/sweet%20potato.jpg?itok=bV9cBraB" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/sweet-potatoes-yams" hreflang="en">
#                  Sweet Potatoes &amp; Yams
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/swiss-chard">
#                 <img alt="bunches of swiss chard" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/swiss%20chard.jpg?itok=6JB5GMnP" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/swiss-chard" hreflang="en">
#                  Swiss Chard
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/turnips">
#                 <img alt="Turnips with green tops" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/turnips.jpg?itok=1h1CIruf" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/turnips" hreflang="en">
#                  Turnips
#                 </a>
#                </h4>
#               </li>
#               <li class="seasonal-produce--season-landing__item">
#                <a href="/seasonal-produce-guide/winter-squash">
#                 <img alt="butternut squash, acorn squash, and other winter squash" height="400" src="/sites/default/files/styles/crop_ratio_7_5_thumb/public/seasonal-produce/2018-05/winter%20squash.jpg?itok=vHhnJvAc" typeof="foaf:Image" width="560"/>
#                </a>
#                <h4>
#                 <a href="/seasonal-produce-guide/winter-squash" hreflang="en">
#                  Winter Squash
#                 </a>
#                </h4>
#               </li>
#              </ul>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </article>
#     </div>
#    </main>
#    <footer class="usa-footer usa-footer-slim">
#     <div class="usa-grid usa-footer-return-to-top">
#      <a href="#">
#       Return to top
#      </a>
#     </div>
#     <div>
#      <div class="usa-footer-primary-section">
#       <div class="usa-grid-full">
#        <nav aria-labelledby="block-mainnavigation-2-menu" class="usa-footer-nav" data-block-plugin-id="system_menu_block:main" id="block-mainnavigation-2">
#         <h2 class="usa-sr-only" id="block-mainnavigation-2-menu">
#          Main footer navigation
#         </h2>
#         <ul class="usa-unstyled-list">
#          <li class="usa-width-one-fourth usa-footer-primary-content">
#           <a class="usa-footer-primary-link" data-drupal-link-system-path="&lt;front&gt;" href="/">
#            <span>
#             Home
#            </span>
#           </a>
#          </li>
#          <li class="usa-width-one-fourth usa-footer-primary-content">
#           <a class="usa-footer-primary-link" data-drupal-link-system-path="node/835" href="/snap-ed-works">
#            <span>
#             SNAP-Ed Works!
#            </span>
#           </a>
#          </li>
#          <li class="usa-width-one-fourth usa-footer-primary-content">
#           <a class="usa-footer-primary-link" data-drupal-link-system-path="node/1817" href="/snap-ed-works/nutrition-education">
#            <span>
#             Nutrition Education
#            </span>
#           </a>
#          </li>
#          <li class="usa-width-one-fourth usa-footer-primary-content">
#           <a class="usa-footer-primary-link" data-drupal-link-system-path="node/578" href="/program-administration">
#            <span>
#             Program Administration
#            </span>
#           </a>
#          </li>
#          <li class="usa-width-one-fourth usa-footer-primary-content">
#           <a class="usa-footer-primary-link" data-drupal-link-system-path="node/579" href="/training">
#            <span>
#             Training
#            </span>
#           </a>
#          </li>
#         </ul>
#        </nav>
#       </div>
#      </div>
#      <div class="usa-footer-secondary_section">
#       <div class="usa-grid-full">
#        <nav aria-labelledby="block-usda-footernavigation-menu" class="usa-footer-nav usa-width-two-thirds" data-block-plugin-id="system_menu_block:footer-navigation" id="block-usda-footernavigation">
#         <h2 class="usa-sr-only" id="block-usda-footernavigation-menu">
#          Footer navigation
#         </h2>
#         <ul class="usa-unstyled-list usda-footer-navigation">
#          <li class="usda-footer-navigation-link">
#           <a data-drupal-link-system-path="sitemap" href="/sitemap">
#            Site Map
#           </a>
#          </li>
#          <li class="usda-footer-navigation-link">
#           <a href="https://www.fns.usda.gov/">
#            FNS
#           </a>
#          </li>
#          <li class="usda-footer-navigation-link">
#           <a href="https://www.usda.gov/">
#            USDA
#           </a>
#          </li>
#          <li class="usda-footer-navigation-link">
#           <a href="https://www.fns.usda.gov/freedom-information-act-foia">
#            FOIA
#           </a>
#          </li>
#          <li class="usda-footer-navigation-link">
#           <a href="https://www.usda.gov/oig/">
#            Visit OIG
#           </a>
#          </li>
#          <li class="usda-footer-navigation-link">
#           <a href="https://www.usda.gov/plain-writing">
#            Plain Writing
#           </a>
#          </li>
#          <li class="usda-footer-navigation-link">
#           <a href="https://www.fns.usda.gov/web-accessibility-statement">
#            Accessibility Statement
#           </a>
#          </li>
#          <li class="usda-footer-navigation-link">
#           <a href="https://www.fns.usda.gov/privacy-policy">
#            Privacy Policy
#           </a>
#          </li>
#          <li class="usda-footer-navigation-link">
#           <a href="https://www.fns.usda.gov/usda-nondiscrimination-statement">
#            Non-Discrimination Statement
#           </a>
#          </li>
#          <li class="usda-footer-navigation-link">
#           <a href="https://www.fns.usda.gov/information-quality">
#            Information Quality
#           </a>
#          </li>
#          <li class="usda-footer-navigation-link">
#           <a href="https://www.usa.gov/">
#            USA.gov
#           </a>
#          </li>
#          <li class="usda-footer-navigation-link">
#           <a href="https://www.whitehouse.gov/">
#            Whitehouse.gov
#           </a>
#          </li>
#         </ul>
#        </nav>
#        <div aria-labelledby="block-footersignup-menu" class="usa-sign_up-block usa-width-one-third" data-block-plugin-id="block_content:771aea9e-aef0-4ad8-a2cf-7fdedb9afc5d" id="block-footersignup">
#         <h3 class="usa-sign_up-header" id="block-footersignup-menu">
#          Sign Up for Updates
#         </h3>
#         <form action="https://public.govdelivery.com/accounts/USFNS/subscribers/qualify">
#          <label class="signup__label" for="block-footersignup-label">
#           Your email address
#          </label>
#          <input name="topic_id" type="hidden" value="USFNS_191"/>
#          <input class="signup__input" id="block-footersignup-label" name="email" type="email"/>
#          <input class="signup__button" name="commit" type="submit" value="Sign Up"/>
#         </form>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="usa-grid usda-footer-branding">
#      <div>
#       <div class="usa-logo">
#        <span class="usda-logo">
#         <img alt="USDA Logo" class="usda-logo-img" src="/themes/usda/img/usda-symbol.svg"/>
#        </span>
#        <a aria-label="The U.S. Department of Agriculture Home Page" class="usda-logo-text" href="/" rel="home" title="Home">
#         <h3>
#          SNAP-Ed Connection
#         </h3>
#         <span>
#          U.S. Department of Agriculture
#         </span>
#        </a>
#       </div>
#      </div>
#      <div class="footer-social">
#       <div class="footer-social-set">
#        <a class="usa-link-twitter" href="https://twitter.com/SNAP_Ed">
#         <span>
#          USDA on Twitter
#         </span>
#        </a>
#       </div>
#      </div>
#     </div>
#    </footer>
#   </div>
#   <script data-drupal-selector="drupal-settings-json" type="application/json">
#    {"path":{"baseUrl":"\/","scriptPath":null,"pathPrefix":"","currentPath":"node\/839","currentPathIsAdmin":false,"isFront":false,"currentLanguage":"en"},"pluralDelimiter":"\u0003","suppressDeprecationErrors":true,"data":{"extlink":{"extTarget":true,"extTargetNoOverride":false,"extNofollow":false,"extNoreferrer":false,"extFollowNoOverride":false,"extClass":"ext","extLabel":"(link is external)","extImgClass":false,"extSubdomains":false,"extExclude":"","extInclude":"","extCssExclude":"nav","extCssExplicit":"main","extAlert":false,"extAlertText":"","mailtoClass":"mailto","mailtoLabel":"(link sends email)","extUseFontAwesome":false,"extIconPlacement":"append","extFaLinkClasses":"fa fa-external-link","extFaMailtoClasses":"fa fa-envelope-o","whitelistedDomains":null}},"ajax":[],"user":{"uid":0,"permissionsHash":"94e3932684c5a7884dad2a378683fc4e26b3f4bfb2e4ab2acac851c31db908aa"}}
#   </script>
#   <script src="/sites/default/files/js/js_5seye2Krcv3rHXfMOD3SF7ePTGUSWoX_Rtapo5rq7Z4.js">
#   </script>
#  </body>
# </html>

# %%
# results are returned as an iterable list
results = soup.find_all('h4', limit=5)
results
# Out:
# [<h4><a href="/seasonal-produce-guide/apples" hreflang="en">Apples</a></h4>,
#  <h4><a href="/seasonal-produce-guide/bananas" hreflang="en">Bananas</a></h4>,
#  <h4><a href="/seasonal-produce-guide/beets" hreflang="en">Beets</a></h4>,
#  <h4><a href="/seasonal-produce-guide/bell-peppers" hreflang="en">Bell Peppers</a></h4>,
#  <h4><a href="/seasonal-produce-guide/broccoli" hreflang="en">Broccoli</a></h4>]

# %%
# Loop through returned results to get firt five seasonal produce in fall
for result in results:
    # Error handling
    try:
        # Identify and return link to listing
        link = result.a['href'].split('/')

        # Print results only if title, price, and link are available
        if link:
            print(link[2])
    except AttributeError as e:
        print(e)
# Out:
# apples
# bananas
# beets
# bell-peppers
# broccoli

# %%
import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/Apple'

# %%
tables = pd.read_html(url)
tables
# Out:
# [                                                Apple  \
#  0                                                 NaN
#  1                    Fruit of the Honeycrisp cultivar
#  2                                                 NaN
#  3                                             Flowers
#  4                           Scientific classification
#  5                                             Domain:
#  6                                            Kingdom:
#  7                                              Clade:
#  8                                              Clade:
#  9                                              Clade:
#  10                                             Clade:
#  11                                             Order:
#  12                                            Family:
#  13                                             Genus:
#  14                                           Species:
#  15                                      Binomial name
# ...

# %%
df = tables[3]
df.head()
# Out:
#   Nutritional value per 100 g (3.5 oz) Nutritional value per 100 g (3.5 oz).1
# 0                               Energy                       218 kJ (52 kcal)
# 1                                  NaN                                    NaN
# 2                        Carbohydrates                                13.81 g
# 3                               Sugars                                  10.39
# 4                        Dietary fiber                                  2.4 g
